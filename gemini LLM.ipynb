# %%
pip install google-genai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting google-genai
#   Downloading google_genai-2.9.0-py3-none-any.whl (950 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 950.8/950.8 KB 1.1 MB/s eta 0:00:00m eta 0:00:010:01:01
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in ./.local/lib/python3.10/site-packages (from google-genai) (0.28.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from google-genai) (1.7.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in ./.local/lib/python3.10/site-packages (from google-genai) (4.14.0)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in ./.local/lib/python3.10/site-packages (from google-genai) (2.32.3)
# Collecting tenacity<9.2.0,>=8.2.3
#   Downloading tenacity-9.1.4-py3-none-any.whl (28 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.12.5 in ./.local/lib/python3.10/site-packages (from google-genai) (2.13.4)
# Collecting websockets<17.0,>=13.0.0
#   Downloading websockets-16.0-cp310-cp310-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (183 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.8/183.8 KB 1.9 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Requirement already satisfied: sniffio in ./.local/lib/python3.10/site-packages (from google-genai) (1.3.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in ./.local/lib/python3.10/site-packages (from google-genai) (4.15.0)
# Collecting google-auth[requests]<3.0.0,>=2.48.1
#   Downloading google_auth-2.55.0-py3-none-any.whl (252 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.4/252.4 KB 1.8 MB/s eta 0:00:002.0 MB/s eta 0:00:01
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./.local/lib/python3.10/site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /usr/lib/python3/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.3)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 KB 1.1 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Collecting cryptography>=38.0.3
#   Downloading cryptography-49.0.0-cp39-abi3-manylinux_2_34_x86_64.whl (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 1.1 MB/s eta 0:00:00m eta 0:00:010:0100:01
# Requirement already satisfied: certifi in /usr/lib/python3/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2020.6.20)
# Requirement already satisfied: httpcore==1.* in ./.local/lib/python3.10/site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./.local/lib/python3.10/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./.local/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (0.4.2)
# Requirement already satisfied: pydantic-core==2.46.4 in ./.local/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (2.46.4)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.local/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (0.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3.0.0,>=2.28.1->google-genai) (1.26.5)
# Collecting cffi>=2.0.0
#   Downloading cffi-2.0.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.5/216.5 KB 592.9 kB/s eta 0:00:00 MB/s eta 0:00:01
# Collecting pyasn1<0.7.0,>=0.6.1
#   Downloading pyasn1-0.6.3-py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 KB 1.1 MB/s eta 0:00:003 kB/s eta 0:00:01
# Collecting pycparser
#   Downloading pycparser-3.0-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 KB 1.1 MB/s eta 0:00:001.3 MB/s eta 0:00:01
# Installing collected packages: websockets, tenacity, pycparser, pyasn1, pyasn1-modules, cffi, cryptography, google-auth, google-genai
# Successfully installed cffi-2.0.0 cryptography-49.0.0 google-auth-2.55.0 google-genai-2.9.0 pyasn1-0.6.3 pyasn1-modules-0.4.2 pycparser-3.0 tenacity-9.1.4 websockets-16.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install -U google-genai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: google-genai in ./.local/lib/python3.10/site-packages (2.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from google-genai) (1.7.0)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in ./.local/lib/python3.10/site-packages (from google-genai) (2.32.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.12.5 in ./.local/lib/python3.10/site-packages (from google-genai) (2.13.4)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in ./.local/lib/python3.10/site-packages (from google-genai) (0.28.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in ./.local/lib/python3.10/site-packages (from google-genai) (4.15.0)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in ./.local/lib/python3.10/site-packages (from google-genai) (9.1.4)
# Requirement already satisfied: google-auth[requests]<3.0.0,>=2.48.1 in ./.local/lib/python3.10/site-packages (from google-genai) (2.55.0)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in ./.local/lib/python3.10/site-packages (from google-genai) (16.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in ./.local/lib/python3.10/site-packages (from google-genai) (4.14.0)
# Requirement already satisfied: sniffio in ./.local/lib/python3.10/site-packages (from google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /usr/lib/python3/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.3)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./.local/lib/python3.10/site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (1.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./.local/lib/python3.10/site-packages (from google-auth[requests]<3.0.0,>=2.48.1->google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in ./.local/lib/python3.10/site-packages (from google-auth[requests]<3.0.0,>=2.48.1->google-genai) (49.0.0)
# Requirement already satisfied: httpcore==1.* in ./.local/lib/python3.10/site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: certifi in /usr/lib/python3/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2020.6.20)
# Requirement already satisfied: h11>=0.16 in ./.local/lib/python3.10/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: pydantic-core==2.46.4 in ./.local/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./.local/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (0.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.local/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (0.7.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3.0.0,>=2.28.1->google-genai) (1.26.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.2)
# Requirement already satisfied: cffi>=2.0.0 in ./.local/lib/python3.10/site-packages (from cryptography>=38.0.3->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (2.0.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in ./.local/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (0.6.3)
# Requirement already satisfied: pycparser in ./.local/lib/python3.10/site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (3.0)

# %%
from google import genai

# %%
API_KEY=""

# %%
client= genai.Client(api_key=API_KEY)

# %%
prompt="what is Ai..?"

# %%
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=prompt
)
print(response.text)
# Out:
# **Artificial Intelligence (AI)** is a broad field of computer science focused on creating machines that can perform tasks that typically require human intelligence.
#
# In simpler terms, it's about making computers "think" and "learn" like humans do, or at least mimic those cognitive functions.
#
# ### What Does AI Do? (Key Abilities)
#
# AI systems are designed to perform tasks that involve:
#
# 1.  **Learning:** Acquiring information and rules for using the information. This often involves processing vast amounts of data to identify patterns.
# 2.  **Reasoning:** Using rules to reach approximate or definite conclusions.
# 3.  **Problem-Solving:** Finding solutions to complex challenges.
# 4.  **Perception:** Interpreting sensory input (like images, sounds, or text) from the world.
# 5.  **Understanding Language:** Processing and generating human language (Natural Language Processing).
# 6.  **Decision-Making:** Choosing actions based on available information and goals.
#
# ### How Does AI Work (Simplified)?
#
# At its core, AI typically involves:
#
# *   **Data:** AI algorithms are trained on massive datasets. The quality and quantity of this data are crucial.
# *   **Algorithms:** These are sets of rules and statistical models that the AI uses to process data, learn from it, and make predictions or decisions.
# *   **Learning:** Instead of being explicitly programmed for every possible scenario, AI systems learn from the data. They identify patterns, make inferences, and improve their performance over time.
#
# ### Types of AI:
#
# 1.  **Narrow AI (or Weak AI):** This is the AI we have today. It's designed and trained for a specific task.
#     *   **Examples:** Siri, Alexa, Google Translate, facial recognition software, recommendation engines (Netflix, Amazon), self-driving cars (they drive, but don't plan your day).
#     *   **Key characteristic:** Excels at its specific task but lacks broader cognitive abilities or general understanding.
#
# 2.  **General AI (or Strong AI / Artificial General Intelligence - AGI):** This is theoretical AI that would possess human-level cognitive abilities across a wide range of tasks. It could understand, learn, and apply intelligence to any intellectual task that a human can.
#     *   **Status:** Does not exist yet. It's a significant goal for AI research.
#
# 3.  **Superintelligence:** This refers to hypothetical AI that would surpass human intelligence in virtually every field, including scientific creativity, general wisdom, and social skills.
#     *   **Status:** Purely theoretical and a subject of much speculation and debate about its potential impact.
#
# ### Key Subfields and Techniques within AI:
#
# *   **Machine Learning (ML):** The most common approach to AI today. It allows systems to learn from data without being explicitly programmed.
#     *   **Deep Learning (DL):** A subset of ML that uses neural networks with many layers (hence "deep") to learn complex patterns, especially good for image recognition and natural language processing.
# *   **Natural Language Processing (NLP):** Enables computers to understand, interpret, and generate human language.
# *   **Computer Vision:** Allows computers to "see" and interpret visual information from images and videos.
# *   **Robotics:** Deals with the design, construction, operation, and use of robots, often incorporating AI for perception, navigation, and decision-making.
# *   **Expert Systems:** Early forms of AI that used rules to mimic the decision-making ability of a human expert.
#
# ### Where Do We See AI? (Applications)
#
# AI is already integrated into many aspects of our daily lives:
#
# *   **Smartphones:** Voice assistants, facial recognition, predictive text.
# *   **Online Services:** Recommendation systems (products, movies, music), search engines, spam filters.
# *   **Healthcare:** Disease diagnosis, drug discovery, personalized treatment plans.
# *   **Finance:** Fraud detection, algorithmic trading, credit scoring.
# *   **Transportation:** Self-driving cars, traffic optimization.
# *   **Manufacturing:** Robotic automation, quality control.
# *   **Customer Service:** Chatbots, virtual assistants.
#
# In essence, AI is a powerful and rapidly evolving technology that seeks to automate, enhance, and ultimately transform how we interact with information and the world around us.
