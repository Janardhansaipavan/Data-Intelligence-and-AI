# %%
list1 =[1,2,3,4,5]
sum1=sum(list1)
print(sum1)
# Out:
# 15

# %%
list2=[11,22,33,44,55]
maxi=max(list2)
mini=min(list2)
print(maxi)
print(mini)
# Out:
# 55
# 11

# %%
list3=[1,2,3,4,5,6]
even=0
odd=0
for i in list3:
    if i%2==0:
        even+=1
    else:
        odd+=1
print(even)
print(odd)
# Out:
# 3
# 3
