# %%
list1=["sai","pavan","punith","shubangi","bhanu"]
freq={}
for i in list1:
    freq[i]=len(i)
print(freq)
# Out:
# {'sai': 3, 'pavan': 5, 'punith': 6, 'shubangi': 8, 'bhanu': 5}

# %%
disct ={
    "name1": "saipavan",
    'age' :20,
    'lk' :32
}
disct1={
    "name1" : "pawan",
    'age' : 20,
    'lk' :23
}
result = disct.copy()
for key, value in disct1.items():
    result[key]=result.get(key,0)+value
print(result)
# Out:
# {'name1': 'saipavanpawan', 'age': 40, 'lk': 55}
